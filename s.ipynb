# %%
import pandas as pd

# %%
df = pd.read_json("static/js/partitions.json")
df
# Out:
#        p0     p1     p2     p3     p4     p5     p6     p7     p8     p9  ...  \
# 0   q1147  q2236  q1331  q2115   q567  q1341   q430  q2007   q404   q313  ...
# 1   q2078  q1290  q1065  q1133  q1951   q939  q2180   q241  q2233  q1938  ...
# 2   q1603  q1476  q2177  q1844   q122   q688  q1913  q1177  q1041   q652  ...
# 3   q1551  q2173  q1919  q1548  q1930   q113  q1795   q540   q294  q1859  ...
# 4    q162  q1756  q2209   q596  q1182  q1943  q1188  q1020  q1989  q2081  ...
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 91  q1704  q1001   q117  q1614  q2028   q921  q1084  q1668  q1272    q33  ...
# 92   q996  q1791   q379  q1275   q896   q130   q487  q1829  q2103   q223  ...
# 93   q293   q376  q1866   q910   q555  q2009  q1543  q2176   q897  q1359  ...
# 94   q333  q1329    q96  q1630  q1918  q1352  q1569    q93  q1684    q69  ...
# 95   q611  q2093  q2159  q1760  q2213  q2068    q78  q1221   q518  q1417  ...
#
# ...

# %%
_df = pd.DataFrame()
for i in range(480):
  _df = pd.concat([_df, df['p'+str(i)]], axis=0)
_df.value_counts()
# Out:
# imc1     480
# imc2     480
# q2013     20
# q324      20
# q319      20
#         ...
# q1668     20
# q1667     20
# q1666     20
# q1665     20
# q999      20
# Length: 2258, dtype: int64

# %%
_df = pd.DataFrame()
for i in range(24):
  _df = pd.concat([_df, df['p'+str(i)]], axis=0)
_df.value_counts()
# Out:
# imc1     24
# imc2     24
# q2013     1
# q324      1
# q319      1
#          ..
# q1668     1
# q1667     1
# q1666     1
# q1665     1
# q999      1
# Length: 2258, dtype: int64
